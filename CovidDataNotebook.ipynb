# %%
import pandas as pd
df = pd.read_csv('CovidDataSQL.csv')

# %%
print (df)
# Out:
#                          Name           Region  Cases cumulative total  \
# 0                      Global              NaN               768187096
# 1    United States of America         Americas               103436829
# 2                       China  Western Pacific                99285177
# 3                       India  South-East Asia                44993543
# 4                      France           Europe                39079469
# ..                        ...              ...                     ...
# 228                      Niue  Western Pacific                     820
# 229                  Holy See           Europe                      26
# 230                   Tokelau  Western Pacific                       5
# 231          Pitcairn Islands  Western Pacific                       4
# 232              Turkmenistan           Europe                       0
#
#      Cases cumulative total per 100000 population  Deaths cumulative total  \
# ...

# %%
df = df.drop_duplicates()
df.head(45)
# Out:
#                           Name                 Region  Cases cumulative total  \
# 0                       Global                    NaN               768187096
# 1     United States of America               Americas               103436829
# 2                        China        Western Pacific                99285177
# 3                        India        South-East Asia                44993543
# 4                       France                 Europe                39079469
# 5                      Germany                 Europe                38434267
# 6                       Brazil               Americas                37639324
# 7                        Japan        Western Pacific                33803572
# 8            Republic of Korea        Western Pacific                32018486
# 9                        Italy                 Europe                25887444
# 10          The United Kingdom                 Europe                24470658
# ...

# %%
df["Name"] = df["Name"].str.strip("123._/")
df["Region"] = df["Region"].str.strip("123._/")
df
# Out:
#                          Name           Region  Cases cumulative total  \
# 0                      Global              NaN               768187096
# 1    United States of America         Americas               103436829
# 2                       China  Western Pacific                99285177
# 3                       India  South-East Asia                44993543
# 4                      France           Europe                39079469
# ..                        ...              ...                     ...
# 228                      Niue  Western Pacific                     820
# 229                  Holy See           Europe                      26
# 230                   Tokelau  Western Pacific                       5
# 231          Pitcairn Islands  Western Pacific                       4
# 232              Turkmenistan           Europe                       0
#
#      Cases cumulative total per 100000 population  Deaths cumulative total  \
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#                          Name           Region  Cases cumulative total  \
# 0                      Global              NaN               768187096
# 1    United States of America         Americas               103436829
# 2                       China  Western Pacific                99285177
# 3                       India  South-East Asia                44993543
# 4                      France           Europe                39079469
# ..                        ...              ...                     ...
# 228                      Niue  Western Pacific                     820
# 229                  Holy See           Europe                      26
# 230                   Tokelau  Western Pacific                       5
# 231          Pitcairn Islands  Western Pacific                       4
# 232              Turkmenistan           Europe                       0
#
#      Cases cumulative total per 100000 population  Deaths cumulative total  \
# ...

# %%
df = df.dropna()
df
# Out:
#                          Name           Region  Cases cumulative total  \
# 1    United States of America         Americas               103436829
# 2                       China  Western Pacific                99285177
# 3                       India  South-East Asia                44993543
# 4                      France           Europe                39079469
# 5                     Germany           Europe                38434267
# ..                        ...              ...                     ...
# 228                      Niue  Western Pacific                     820
# 229                  Holy See           Europe                      26
# 230                   Tokelau  Western Pacific                       5
# 231          Pitcairn Islands  Western Pacific                       4
# 232              Turkmenistan           Europe                       0
#
#      Cases cumulative total per 100000 population  Deaths cumulative total  \
# ...

# %%
df.to_csv(r"C:\Users\Student\Desktop\export_dataframe.csv")

print(df)
# Out:
#                          Name           Region  Cases cumulative total  \
# 1    United States of America         Americas               103436829
# 2                       China  Western Pacific                99285177
# 3                       India  South-East Asia                44993543
# 4                      France           Europe                39079469
# 5                     Germany           Europe                38434267
# ..                        ...              ...                     ...
# 228                      Niue  Western Pacific                     820
# 229                  Holy See           Europe                      26
# 230                   Tokelau  Western Pacific                       5
# 231          Pitcairn Islands  Western Pacific                       4
# 232              Turkmenistan           Europe                       0
#
#      Cases cumulative total per 100000 population  Deaths cumulative total  \
# ...
